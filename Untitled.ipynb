# %%
import spacy
nlp = spacy.load('en_core_web_md')

# %%
import pickle
infile = open('token_save.pkl','rb')
tokenizer = pickle.load(infile)
infile.close()

# %%
from tensorflow.keras.models import load_model
model = load_model('epochBIG.h5')
# Out:
# WARNING:tensorflow:From C:\Users\Dr. Mahendra Yadav\Anaconda3\lib\site-packages\tensorflow\python\keras\initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\Dr. Mahendra Yadav\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.sequence import pad_sequences
def transform(input_sent, model, tokenizer):
  word_list = input_sent.split()
  print("ded")
  result = word_list[0] +' '+ word_list[1]
  for i in range(len(word_list)-2):
    encoded_text = tokenizer.texts_to_sequences([result])[0]
    pad_encoded = pad_sequences([encoded_text], maxlen=25, truncating='pre')
    pred_word_ind = model.predict(pad_encoded, verbose=0)[0]
    pred_word_ind = pred_word_ind.argsort()[-3:][::-1]
    indx = 0
    similarity = 0
    for j in range(3):
        try:
            this_sim = nlp(str(tokenizer.index_word[pred_word_ind[j]])).similarity(str(nlp(tokenizer.index_word[word_list[i]])))
            if this_sim > similarity:
                indx = j
                similarity = nlp(str(tokenizer.index_word[pred_word_ind[j]])).similarity(str(nlp(tokenizer.index_word[word_list[i]])))
        except:
            indx = 0
    pred_word = tokenizer.index_word[pred_word_ind[indx]] 
    result += ' ' + pred_word

  return result

# %%
nlp(u'lion').similarity(nlp(u'lion'))
tokenizer.index_word
# Out:
# {1: 'the',
#  2: 'and',
#  3: 'i',
#  4: 'of',
#  5: 'to',
#  6: 'you',
#  7: 'a',
#  8: 'in',
#  9: 'that',
#  10: 'is',
#  11: 'not',
#  12: 'brutus.',
#  13: 'with',
#  14: 'for',
#  15: 'this',
#  16: 'my',
#  17: 'he',
#  18: 'it',
#  19: 'be',
#  20: 'his',
#  21: 'have',
#  22: 'cassius.',
#  23: 'as',
#  24: 'your',
#  25: 'will',
#  26: 'do',
#  27: 'but',
#  28: 'are',
#  29: 'shall',
#  30: 'by',
#  31: 'me',
#  32: 'or',
#  33: 'what',
#  34: 'thou',
#  35: 'all',
#  36: 'if',
#  37: 'we',
#  38: 'caesar',
#  39: 'so',
#  40: 'him',
#  41: 'our',
#  42: 'project',
#  43: 'no',
#  44: 'on',
#  45: 'at',
#  46: 'antony.',
#  47: 'did',
#  48: 'brutus',
#  49: 'citizen.',
#  50: 'when',
#  51: 'was',
#  52: 'they',
#  53: 'good',
#  54: 'their',
#  55: 'let',
#  56: 'from',
#  57: 'caesar.',
#  58: 'know',
#  59: 'am',
#  60: 'enter',
#  61: 'thy',
#  62: 'gutenberg-tm',
#  63: 'brutus,',
#  64: 'come',
#  65: 'which',
#  66: 'any',
#  67: 'may',
#  68: 'o',
#  69: 'upon',
#  70: 'must',
#  71: 'would',
#  72: 'than',
#  73: 'us',
#  74: 'then',
#  75: 'there',
#  76: 'some',
#  77: 'such',
#  78: 'caesar,',
#  79: 'casca.',
#  80: 'should',
#  81: 'caesar’s',
#  82: 'these',
#  83: 'here',
#  84: 'work',
#  85: 'give',
#  86: 'scene',
#  87: 'them',
#  88: 'like',
#  89: 'men',
#  90: 'now',
#  91: 'go',
#  92: 'tell',
#  93: 'how',
#  94: 'cassius,',
#  95: 'me,',
#  96: 'an',
#  97: 'man',
#  98: 'hath',
#  99: 'noble',
#  100: 'were',
#  101: 'you,',
#  102: 'yet',
#  103: 'hear',
#  104: 'see',
#  105: 'mark',
#  106: 'most',
#  107: 'lucius.',
#  108: 'messala.',
#  109: 'where',
#  110: 'thee',
#  111: 'can',
#  112: 'up',
#  113: 'well',
#  114: 'him.',
#  115: 'first',
#  116: 'other',
#  117: 'more',
#  118: 'who',
#  119: 'speak',
#  120: 'love',
#  121: 'electronic',
#  122: 'about',
#  123: '”',
#  124: 'great',
#  125: 'make',
#  126: 'doth',
#  127: 'had',
#  128: 'one',
#  129: 'him,',
#  130: 'gutenberg',
#  131: 'cassius',
#  132: 'much',
#  133: 'second',
#  134: 'nor',
#  135: 'stand',
#  136: '’tis',
#  137: 'say',
#  138: 'it.',
#  139: 'antony',
#  140: 'not,',
#  141: 'why',
#  142: 'till',
#  143: 'every',
#  144: 'take',
#  145: 'terms',
#  146: 'art',
#  147: 'you.',
#  148: 'antony,',
#  149: 'bear',
#  150: 'think',
#  151: 'now,',
#  152: 'o,',
#  153: 'full',
#  154: 'works',
#  155: 'set',
#  156: 'fear',
#  157: 'cinna.',
#  158: 'octavius.',
#  159: 'before',
#  160: 'why,',
#  161: 'mine',
#  162: 'sir,',
#  163: 'time',
#  164: 'look',
#  165: 'third',
#  166: 'portia.',
#  167: 'copyright',
#  168: 'but,',
#  169: 'and,',
#  170: 'could',
#  171: 'me.',
#  172: 'even',
#  173: 'use',
#  174: 'part',
#  175: 'casca,',
#  176: 'citizens.',
#  177: 'many',
#  178: 'find',
#  179: 'ho!',
#  180: 'bid',
#  181: 'no,',
#  182: 'friends,',
#  183: 'what,',
#  184: 'put',
#  185: 'comes',
#  186: 'men,',
#  187: 'lord.',
#  188: 'leave',
#  189: 'meet',
#  190: 'servant.',
#  191: 'fourth',
#  192: 'under',
#  193: 'rome,',
#  194: 'day',
#  195: 'out',
#  196: 'into',
#  197: '[_exeunt._]',
#  198: 'too',
#  199: 'then,',
#  200: 'ay,',
#  201: 'forth',
#  202: 'we’ll',
#  203: 'heart',
#  204: 'united',
#  205: 'another',
#  206: 'people',
#  207: 'never',
#  208: '[_exit',
#  209: 'things',
#  210: 'read',
#  211: 'decius.',
#  212: 'foundation',
#  213: 'donations',
#  214: 'i.',
#  215: 'rome.',
#  216: 'brutus’',
#  217: 'without',
#  218: 'ever',
#  219: 'i’ll',
#  220: 'here,',
#  221: 'very',
#  222: 'hold',
#  223: 'hast',
#  224: 'rome',
#  225: 'will,',
#  226: 'unto',
#  227: 'done',
#  228: 'come,',
#  229: 'blood',
#  230: 'lucilius.',
#  231: 'literary',
#  232: 'archive',
#  233: 'act',
#  234: 'within',
#  235: 'young',
#  236: 'myself',
#  237: 'run',
#  238: 'keep',
#  239: 'soothsayer.',
#  240: 'lord?',
#  241: 'show',
#  242: 'so.',
#  243: 'this,',
#  244: 'thus',
#  245: 'hand,',
#  246: 'honourable',
#  247: 'night,',
#  248: 'send',
#  249: 'mighty',
#  250: 'not.',
#  251: 'cause',
#  252: 'stay',
#  253: 'states',
#  254: 'license',
#  255: 'after',
#  256: 'death.',
#  257: 'lucius,',
#  258: 'get',
#  259: 'best',
#  260: 'follow',
#  261: 'made',
#  262: '[_exeunt',
#  263: 'down',
#  264: 'caesar!',
#  265: 'hand',
#  266: 'look,',
#  267: 'might',
#  268: 'i,',
#  269: 'name',
#  270: 'you;',
#  271: 'gods,',
#  272: 'us.',
#  273: 'him;',
#  274: 'please',
#  275: 'word',
#  276: 'so,',
#  277: 'thee,',
#  278: 'wrong',
#  279: 'titinius.',
#  280: 'clitus.',
#  281: 'paragraph',
#  282: 'it,',
#  283: 'ii.',
#  284: 'same.',
#  285: 'iii.',
#  286: 'near',
#  287: 'field.',
#  288: 'octavius',
#  289: 'against',
#  290: 'messala,',
#  291: 'being',
#  292: 'dost',
#  293: 'poor',
#  294: 'else',
#  295: 'caesar;',
#  296: 'off',
#  297: 'only',
#  298: 'therefore',
#  299: 'well,',
#  300: 'death',
#  301: 'roman',
#  302: 'true',
#  303: 'those',
#  304: 'better',
#  305: '[_exit._]',
#  306: 'bring',
#  307: 'caius',
#  308: 'lord,',
#  309: 'octavius,',
#  310: 'access',
#  311: 'world',
#  312: 'laws',
#  313: 'capitol.',
#  314: 'metellus',
#  315: 'titinius,',
#  316: 'answer',
#  317: 'them.',
#  318: 'her',
#  319: 'gods',
#  320: 'way',
#  321: 'calphurnia.',
#  322: 'friend',
#  323: 'means',
#  324: 'cannot',
#  325: 'gentle',
#  326: 'common',
#  327: 'general',
#  328: 'both',
#  329: 'free',
#  330: 'romans',
#  331: 'man,',
#  332: 'fire',
#  333: 'right',
#  334: 'fell',
#  335: 'own',
#  336: 'night',
#  337: 'bears',
#  338: 'two',
#  339: 'trebonius.',
#  340: 'die',
#  341: 'agree',
#  342: 'agreement',
#  343: 'julius',
#  344: 'copy',
#  345: 'public',
#  346: 'same',
#  347: 'marcus',
#  348: 'lucilius,',
#  349: 'walk',
#  350: 'you?',
#  351: 'indeed,',
#  352: 'bad',
#  353: 'out,',
#  354: 'saw',
#  355: 'peace,',
#  356: 'says',
#  357: 'cry',
#  358: 'spirit',
#  359: 'eyes',
#  360: 'turn',
#  361: 'worthy',
#  362: 'yourself',
#  363: 'honour',
#  364: 'ye',
#  365: 'dear',
#  366: 'state',
#  367: 'rather',
#  368: 'today.',
#  369: 'too.',
#  370: 'that,',
#  371: 'mean',
#  372: 'been',
#  373: 'again,',
#  374: 'well.',
#  375: 'so;',
#  376: 'days',
#  377: 'life',
#  378: 'stir',
#  379: 'found',
#  380: 'boy,',
#  381: 'hands',
#  382: 'bloody',
#  383: 'away,',
#  384: 'charge',
#  385: 'soldier.',
#  386: 'titinius',
#  387: 'fee',
#  388: 'including',
#  389: 'ebook',
#  390: 'located',
#  391: 'country',
#  392: 'last',
#  393: 'room',
#  394: 'philippi.',
#  395: 'cinna,',
#  396: 'cobbler.',
#  397: 'old',
#  398: 'work.',
#  399: 'so?',
#  400: 'me?',
#  401: 'ides',
#  402: 'heard',
#  403: 'seek',
#  404: 'alas,',
#  405: 'them,',
#  406: 'man.',
#  407: 'seen',
#  408: 'through',
#  409: 'not?',
#  410: 'part,',
#  411: 'durst',
#  412: 'sure',
#  413: 'face',
#  414: 'several',
#  415: 'sword,',
#  416: 'strong',
#  417: 'appear',
#  418: 'us,',
#  419: 'is,',
#  420: 'death,',
#  421: 'ligarius.',
#  422: 'she',
#  423: 'will.',
#  424: 'place',
#  425: 'thee.',
#  426: 'whilst',
#  427: 'didst',
#  428: 'received',
#  429: 'philippi',
#  430: 'associated',
#  431: 'u.s.',
#  432: 'copies',
#  433: 'section',
#  434: 'work,',
#  435: 'refund',
#  436: 'information',
#  437: 'away',
#  438: 'using',
#  439: 'street.',
#  440: 'house',
#  441: 'tent',
#  442: 'decius',
#  443: 'poet.',
#  444: 'cato,',
#  445: 'friends',
#  446: 'portia,',
#  447: 'marullus.',
#  448: 'respect',
#  449: 'say,',
#  450: 'me;',
#  451: 'live',
#  452: 'wherefore',
#  453: 'lead',
#  454: 'over',
#  455: 'pompey’s',
#  456: 'fall',
#  457: 'pray',
#  458: 'go,',
#  459: 'countrymen,',
#  460: 'whether',
#  461: 'fly',
#  462: 'strange',
#  463: 'loves',
#  464: 'himself',
#  465: 'men.',
#  466: 'since',
#  467: 'virtue',
#  468: 'thing',
#  469: 'cold',
#  470: 'word,',
#  471: 'ere',
#  472: 'fly,',
#  473: 'went',
#  474: 'nothing',
#  475: 'thought',
#  476: 'friend,',
#  477: 'done,',
#  478: 'casca',
#  479: 'sleep',
#  480: 'antony;',
#  481: 'crown',
#  482: 'not;',
#  483: 'came',
#  484: 'down,',
#  485: 'three',
#  486: 'there’s',
#  487: 'fare',
#  488: 'remember',
#  489: 'home',
#  490: 'brutus._]',
#  491: 'cicero.',
#  492: 'farewell,',
#  493: 'dead,',
#  494: 'vile',
#  495: 'far',
#  496: 'certain',
#  497: 'cinna;',
#  498: 'yes,',
#  499: 'call',
#  500: 'kill',
#  501: 'lie',
#  502: 'march',
#  503: 'hide',
#  504: 'on,',
#  505: 'wish',
#  506: 'lies',
#  507: 'romans,',
#  508: 'him?',
#  509: 'know,',
#  510: 'fetch',
#  511: 'talk',
#  512: 'end',
#  513: 'come.',
#  514: 'enemy',
#  515: 'prepare',
#  516: 'stand,',
#  517: 'law',
#  518: 'number',
#  519: 'master',
#  520: 'though',
#  521: 'receive',
#  522: 'will!',
#  523: 'pindarus.',
#  524: 'varro.',
#  525: 'volumnius.',
#  526: 'distribute',
#  527: 'permission',
#  528: 'distributing',
#  529: 'distribution',
#  530: 'comply',
#  531: 'agreement,',
#  532: 'paid',
#  533: 'provide',
#  534: 'tax',
#  535: 'volunteers',
#  536: 'shakespeare',
#  537: 'almost',
#  538: 'place.',
#  539: 'street',
#  540: 'capitol;',
#  541: 'senate',
#  542: 'house.',
#  543: 'strato,',
#  544: 'flavius.',
#  545: 'hence!',
#  546: 'speak,',
#  547: 'truly,',
#  548: 'nay,',
#  549: 'that?',
#  550: 'pass',
#  551: 'all.',
#  552: 'perceive',
#  553: 'decius,',
#  554: 'directly',
#  555: 'shake',
#  556: 'press',
#  557: 'tongue',
#  558: 'speak.',
#  559: 'once',
#  560: 'further',
#  561: 'eye',
#  562: 'cassius;',
#  563: 'endure',
#  564: 'once,',
#  565: 'said',
#  566: 'thou,',
#  567: 'hearts',
#  568: 'whose',
#  569: 'sick',
#  570: 'world,',
#  571: 'honours',
#  572: 'to,',
#  573: 'said,',
#  574: 'high',
#  575: 'weak',
#  576: 'words',
#  577: 'rest',
#  578: 'cicero',
#  579: 'looks',
#  580: 'capitol,',
#  581: 'has',
#  582: 'he’s',
#  583: 'offer’d',
#  584: 'hands,',
#  585: 'anything',
#  586: 'forth.',
#  587: 'farewell',
#  588: 'fellow',
#  589: 'see,',
#  590: 'sword',
#  591: 'brought',
#  592: 'left',
#  593: 'senators',
#  594: 'base',
#  595: 'goes',
#  596: 'need',
#  597: 'lest',
#  598: 'took',
#  599: 'lucius._]',
#  600: 'little',
#  601: 'brother',
#  602: 'wilt',
#  603: 'enough',
#  604: 'morrow,',
#  605: 'do,',
#  606: 'metellus.',
#  607: 'seem',
#  608: 'cut',
#  609: 'spirit,',
#  610: 'let’s',
#  611: 'live,',
#  612: 'today',
#  613: 'hither,',
#  614: 'men;',
#  615: 'gave',
#  616: 'which,',
#  617: 'tonight',
#  618: 'heart.',
#  619: 'lucius',
#  620: 'ligarius,',
#  621: 'brave',
#  622: 'on.',
#  623: 'blood,',
#  624: 'pardon',
#  625: 'publius.',
#  626: 'blame',
#  627: 'makes',
#  628: 'hand.',
#  629: 'voice',
#  630: 'deed',
#  631: 'all,',
#  632: 'reasons',
#  633: 'funeral.',
#  634: 'body.',
#  635: 'more.',
#  636: 'tear',
#  637: 'pindarus',
#  638: 'ill',
#  639: 'claudius.',
#  640: 'unless',
#  641: 'alarum.',
#  642: 'ride,',
#  643: 'protected',
#  644: 'works,',
#  645: 'trademark',
#  646: '"project',
#  647: 'works.',
#  648: 'its',
#  649: 'web',
#  650: 'replacement',
#  651: 'limited',
#  652: 'parts',
#  653: 'foundation,',
#  654: 'new',
#  655: 'online',
#  656: 'states,',
#  657: 'check',
#  658: '***',
#  659: 'start',
#  660: 'twenty',
#  661: 'iv.',
#  662: 'tent,',
#  663: 'lepidus,',
#  664: 'popilius',
#  665: 'flavius,',
#  666: 'pindarus,',
#  667: 'senators,',
#  668: 'sign',
#  669: 'thou?',
#  670: 'directly.',
#  671: 'yet,',
#  672: 'withal',
#  673: 'wear',
#  674: 'grace',
#  675: 'hard',
#  676: 'yea,',
#  677: 'tiber',
#  678: 'weep',
#  679: 'pluck’d',
#  680: 'casca;',
#  681: 'noise',
#  682: 'peace',
#  683: 'beware',
#  684: 'do.',
#  685: 'myself.',
#  686: 'hard,',
#  687: 'dangerous.',
#  688: 'it?',
#  689: 'day,',
#  690: 'angry',
#  691: 'in,',
#  692: 'bade',
#  693: 'point',
#  694: 'cried,',
#  695: 'body,',
#  696: 'fit',
#  697: 'lose',
#  698: 'write',
#  699: 'feeble',
#  700: 'believe',
#  701: 'th’',
#  702: 'patience',
#  703: 'son',
#  704: 'lay',
#  705: 'glad',
#  706: 'struck',
#  707: 'pluck',
#  708: 'note',
#  709: 'matter',
#  710: 'fear,',
#  711: 'quite',
#  712: 'mov’d',
#  713: 'smile',
#  714: 'behold',
#  715: 'ear',
#  716: 'back',
#  717: 'honest',
#  718: 'because',
#  719: 'taken',
#  720: 'anything?',
#  721: 'mind',
#  722: 'good.',
#  723: 'gives',
#  724: 'minds',
#  725: 'humour',
#  726: 'wherein',
#  727: 'earth',
#  728: 'either',
#  729: 'held',
#  730: 'burn',
#  731: 'besides,',
#  732: 'fire,',
#  733: 'purpose',
#  734: 'who’s',
#  735: 'tempt',
#  736: 'dreadful',
#  737: 'change',
#  738: 'monstrous',
#  739: 'place,',
#  740: 'links',
#  741: 'friend.',
#  742: 'awake',
#  743: 'lucius!',
#  744: 'call’d',
#  745: 'taper',
#  746: 'sir.',
#  747: 'up,',
#  748: 'nature',
#  749: 'cimber',
#  750: 'brutus;',
#  751: 'along',
#  752: 'welcome',
#  753: 'themselves',
#  754: 'break',
#  755: 'here?',
#  756: 'hence,',
#  757: 'be,',
#  758: 'off,',
#  759: 'off.',
#  760: 'given',
#  761: 'peace!',
#  762: 'then.',
#  763: 'none',
#  764: 'yourselves',
#  765: 'dare',
#  766: 'love,',
#  767: 'visit',
#  768: 'hark,',
#  769: 'run,',
#  770: 'battle',
#  771: 'valiant',
#  772: 'forth,',
#  773: 'himself,',
#  774: 'reason',
#  775: 'cinna',
#  776: 'publius',
#  777: '[_aside._]',
#  778: 'we,',
#  779: 'artemidorus.',
#  780: 'return',
#  781: 'suit',
#  782: 'satisfied.',
#  783: 'beg',
#  784: 'constant',
#  785: 'he,',
#  786: 'mutiny.',
#  787: 'red',
#  788: 'dead',
#  789: 'honour,',
#  790: 'business',
#  791: 'that’s',
#  792: 'speech',
#  793: 'shalt',
#  794: 'loved',
#  795: 'offended.',
#  796: 'who,',
#  797: 'rest,',
#  798: 'cassius’',
#  799: 'while',
#  800: 'notice',
#  801: 'heart,',
#  802: 'denied',
#  803: 'money',
#  804: 'lucilius',
#  805: 'letters',
#  806: 'bound',
#  807: 'gown.',
#  808: 'claudius!',
#  809: 'sirs,',
#  810: 'ghost.',
#  811: 'below.',
#  812: 'dardanius.',
#  813: 'strato.',
#  814: 'creating',
#  815: 'ebooks',
#  816: 'mission',
#  817: 'phrase',
#  818: 'person',
#  819: 'gutenberg"',
#  820: 'individual',
#  821: 'states.',
#  822: 'freely',
#  823: 'compliance',
#  824: 'format',
#  825: 'status',
#  826: 'posted',
#  827: 'providing',
#  828: 'additional',
#  829: 'copy,',
#  830: 'site',
#  831: 'provided',
#  832: '*',
#  833: 'contact',
#  834: 'anyone',
#  835: 'william',
#  836: 'pg',
#  837: 'camp',
#  838: 'plains',
#  839: 'field',
#  840: 'cicero,',
#  841: 'publius,',
#  842: 'senators.',
#  843: 'trebonius,',
#  844: 'artemidorus,',
#  845: 'volumnius,',
#  846: 'clitus,',
#  847: 'wife',
#  848: 'ghost',
#  849: 'citizens,',
#  850: 'throng',
#  851: 'idle',
#  852: 'home.',
#  853: 'trade',
#  854: 'knave,',
#  855: 'beseech',
#  856: 'saucy',
#  857: 'proper',
#  858: 'gone',
#  859: 'conquest',
#  860: 'brings',
#  861: 'worse',
#  862: 'hearts,',
#  863: 'knew',
#  864: 'oft',
#  865: 'walls',
#  866: 'patient',
#  867: 'streets',
#  868: 'way,',
#  869: 'triumph',
#  870: 'light',
#  871: 'kiss',
#  872: 'ceremonies.',
#  873: 'too,',
#  874: 'ordinary',
#  875: 'crowd',
#  876: 'forget',
#  877: 'out.',
#  878: 'ha!',
#  879: 'turn’d',
#  880: 'march.',
#  881: 'fellow,',
#  882: 'again.',
#  883: 'order',
#  884: 'trouble',
#  885: 'myself,',
#  886: 'construe',
#  887: 'war,',
#  888: 'buried',
#  889: 'thoughts',
#  890: 'dangers',
#  891: 'therefore,',
#  892: 'discover',
#  893: 'of.',
#  894: 'them;',
#  895: 'choose',
#  896: 'toward',
#  897: 'flood,',
#  898: 'was,',
#  899: 'become',
#  900: 'true,',
#  901: 'coward',
#  902: 'lips',
#  903: 'huge',
#  904: 'ourselves',
#  905: 'yours',
#  906: 'sound',
#  907: 'soon',
#  908: 'grown',
#  909: 'entreat',
#  910: 'things.',
#  911: 'caesar?',
#  912: 'anything.',
#  913: 'greater',
#  914: 'today,',
#  915: 'chanc’d.',
#  916: 'for?',
#  917: '’twas',
#  918: 'told',
#  919: 'fingers',
#  920: 'crown,',
#  921: 'down.',
#  922: 'according',
#  923: 'stood',
#  924: 'sad',
#  925: 'spoke',
#  926: 'ne’er',
#  927: 'enterprise,',
#  928: 'form.',
#  929: 'you:',
#  930: 'so:',
#  931: 'world.',
#  932: 'opinion',
#  933: 'sure,',
#  934: 'fire.',
#  935: 'heaven,',
#  936: 'capitol',
#  937: 'hundred',
#  938: 'streets.',
#  939: 'upon.',
#  940: 'time.',
#  941: 'in.',
#  942: 'heavens',
#  943: 'faults.',
#  944: 'night;',
#  945: 'cross',
#  946: 'present',
#  947: 'quality',
#  948: 'spirits,',
#  949: 'are.',
#  950: 'cassius?',
#  951: 'save',
#  952: 'dagger',
#  953: 'life,',
#  954: 'power',
#  955: 'tyranny',
#  956: 'pleasure.',
#  957: 'trash',
#  958: 'led',
#  959: 'made.',
#  960: 'already',
#  961: 'enterprise',
#  962: 'fearful',
#  963: 'close',
#  964: 'it;',
#  965: 'trebonius',
#  966: 'offence',
#  967: 'here.',
#  968: 'turns',
#  969: 'kind',
#  970: 'bed.',
#  971: 'day.',
#  972: 'often',
#  973: 'up.',
#  974: 'piece',
#  975: 'man’s',
#  976: 'desire',
#  977: 'half',
#  978: 'dangerous',
#  979: 'none,',
#  980: 'night.',
#  981: 'cimber.',
#  982: 'swear',
#  983: 'each',
#  984: 'drop',
#  985: 'steel',
#  986: 'spirits',
#  987: 'commend',
#  988: 'caesar:',
#  989: 'bleed',
#  990: 'him:',
#  991: 'die;',
#  992: 'metellus,',
#  993: 'fast',
#  994: 'answer’d',
#  995: 'fearing',
#  996: 'hour',
#  997: 'health,',
#  998: 'sick,',
#  999: 'physical',
#  1000: 'mind,',
#  ...}

# %%
transform(input_sent='this time we are going to do some stuff ', model=model, tokenizer=tokenizer)
# Out:
# ded
# 'this time were here as but i fear you,'
